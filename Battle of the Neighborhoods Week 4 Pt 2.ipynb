# %% [markdown]
# ### Battle of the Neighborhood Capstone Project - Week 4 Part 2

# %% [markdown]
# ### Introduction:
# The purpose of this project is to help people to exploring better facilities around their neighborhood. It will help people to make smart and efficient decision on selecting the right or quick access to move around their neighborhood using mapped information on bike movement around Toronto city.
# A lot of people are migrating to Canada and there is a growing need for greener cities and Bicycle movement is one of the greener ways to move around the city.
# Easy identification of mapped bike ways will a long way help and ease movement around the neighborhood.
# Proper documentation of these path and other information will help a great deal.
# The City installs bicycle post-and-rings within the public right-of-way, typically on City of Toronto sidewalks and boulevards, wherever public bicycle parking facilities are needed.

# %% [markdown]
# ### Problem we tried to Solve:
# For new migrant to move around the city, there are designated bicycle route and parks to make the ease of movement to Super Market, Cinema, School or nearest Sport Centre.
# These information at the tip of the finger will aid ease of movement.
# Problem we seek to solve:
# 1.	Sort a list of path and location in Neighborhood in Toronto
# 2.	Sort a list of bicycles post available around Toronto.

# %% [markdown]
# ### Sources of Data to be Used.
# Data Source Description:
# <p>
# Source Link1
# Data Link: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# Source Link2:
# Data Link: https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show
# </p>
# Both links above are sources of information to be used.

# %% [markdown]
# #### Toronto Open-data:
# We will need data from the various neighborhoods, to generate the right cluster information.
# The source of information we are using is a targeted detailed data to help match and compare the various neighborhood.
# These datasets will consist of the street address, Serial Id, Longitude and Latitude etc.
# Here is some information
# 1. Neighborhood
# 2. Neighborhood Latitude
# 3. Neighborhood Longitude
# 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category

# %%
import pandas as pd
import requests

# Get the dataset metadata by passing package_id to the package_search endpoint
# For example, to retrieve the metadata for this dataset:

url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show"
params = { "id": "71e6c206-96e1-48f1-8f6f-0e804687e3be"}
package = requests.get(url, params = params).json()
print(package["result"])

# Get the data by passing the resource_id to the datastore_search endpoint
# See https://docs.ckan.org/en/latest/maintaining/datastore.html for detailed parameters options
# For example, to retrieve the data content for the first resource in the datastore:

for idx, resource in enumerate(package["result"]["resources"]):
    if resource["datastore_active"]:
        url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/datastore_search"
        p = { "id": resource["id"] }
        data = requests.get(url, params = p).json()
        df = pd.DataFrame(data["result"]["records"])
        break
df
# Out:
# {'license_title': 'Open Government Licence – Toronto', 'owner_unit': None, 'relationships_as_object': [], 'topics': 'Transportation,Health', 'owner_email': 'Sandro.Tersigni@toronto.ca', 'excerpt': "Bike Parking location and asset type data maintained by the City of Toronto's Bike Parking Program.\r\n", 'private': False, 'owner_division': 'Transportation Services', 'num_tags': 6, 'id': '71e6c206-96e1-48f1-8f6f-0e804687e3be', 'metadata_created': '2019-07-23T18:01:58.028981', 'refresh_rate': 'Daily', 'title': 'Street Furniture - Bicycle Parking', 'license_url': 'https://open.toronto.ca/open-data-license/', 'state': 'active', 'information_url': 'http://gis.toronto.ca/arcgis/rest/services/primary/cot_geospatial2_mtm/MapServer/27', 'license_id': 'open-government-licence-toronto', 'type': 'dataset', 'resources': [{'cache_last_updated': None, 'package_id': '71e6c206-96e1-48f1-8f6f-0e804687e3be', 'datastore_active': True, 'id': 'e0700d94-0c4d-4058-9354-a4b397c0b249', 'size': None, 'format': '
# ...

# %%
df.head()
# Out:
#        _id  OBJECTID        ID ADDRESSNUMBERTEXT   ADDRESSSTREET  \
# 0  5415510         4  BP-11699                70     The Pond Rd
# 1  5415511         9  BP-11900                 8  Assiniboine Rd
# 2  5415512        66  BP-03501                 8  Kensington Ave
# 3  5415513       109  BP-12883                21      Canniff St
# 4  5415514       174  BP-03939                50   Blue Jays Way
#
#   FRONTINGSTREET  SIDE      FROMSTREET DIRECTION SITEID WARD  \
# 0           None  None     Seneca Lane      None   None   07
# 1           None  None       Nelson Rd      None   None   07
# 2           None  None  Kensington Ave      None   None   11
# 3           None  None    Strachan Ave      None   None   10
# 4           None  None       Mercer St      None   None   10
#
#                               BIA ASSETTYPE               STATUS  \
# 0                            None      Rack             Existing
# 1                            None      Rack             Existing
# ...

# %%
df_1 = df[['_id','X','Y','LONGITUDE','LATITUDE']]
print(df_1)
# Out:
#         _id           X            Y  LONGITUDE   LATITUDE
# 0   5415510  304813.343  4847867.805 -79.499834  43.770770
# 1   5415511  304460.910  4847578.496 -79.504212  43.768166
# 2   5415512  312856.125  4834795.334 -79.400127  43.653058
# 3   5415513  311940.672  4833504.872 -79.411493  43.641451
# 4   5415514  313503.184  4833936.254 -79.392120  43.645318
# ..      ...         ...          ...        ...        ...
# 95  5415605  314238.924  4834548.829 -79.382989  43.650823
# 96  5415606  314966.371  4836379.727 -79.373937  43.667294
# 97  5415607  314963.383  4836378.635 -79.373974  43.667284
# 98  5415608  312379.455  4833039.774 -79.406061  43.637260
# 99  5415609  312380.396  4833040.136 -79.406050  43.637264
#
# [100 rows x 5 columns]

# %%
df_1.describe()
# Out:
#                 _id             X             Y   LONGITUDE    LATITUDE
# count  1.000000e+02     100.00000  1.000000e+02  100.000000  100.000000
# mean   5.415560e+06  312441.69661  4.836049e+06  -79.405252   43.664343
# std    2.901149e+01    2729.11069  3.128093e+03    0.033837    0.028161
# min    5.415510e+06  304032.94600  4.831217e+06  -79.509508   43.620890
# 25%    5.415535e+06  311115.27925  4.834339e+06  -79.421696   43.648941
# 50%    5.415560e+06  312970.54850  4.834926e+06  -79.398617   43.654262
# 75%    5.415584e+06  313852.77850  4.836639e+06  -79.387742   43.669680
# max    5.415609e+06  317989.59700  4.847868e+06  -79.336464   43.770770

# %%
df_1.iloc[:10]
# Out:
#        _id           X            Y  LONGITUDE   LATITUDE
# 0  5415510  304813.343  4847867.805 -79.499834  43.770770
# 1  5415511  304460.910  4847578.496 -79.504212  43.768166
# 2  5415512  312856.125  4834795.334 -79.400127  43.653058
# 3  5415513  311940.672  4833504.872 -79.411493  43.641451
# 4  5415514  313503.184  4833936.254 -79.392120  43.645318
# 5  5415515  309323.837  4835314.509 -79.443913  43.657761
# 6  5415516  310973.155  4837275.766 -79.423442  43.675403
# 7  5415517  314695.814  4834615.514 -79.377324  43.651417
# 8  5415518  313809.734  4837004.765 -79.388269  43.672935
# 9  5415519  311736.367  4833336.570 -79.414028  43.639938

# %% [markdown]
# ### Methodology Used:
# K means was employed to test the Unsupervised data and various machine learning algorithm were employed. Since the centroid of the data was selected arbitrarily and this is inline with unsupervised data and computational approach.
# It therefore shows that the various point picked randomly have certain level of accuracy in terms of the clusters. And the outliers’ value did not by anyway affect the final outcome of the data analysis.
# Information gathered was employed Sources shows that there were more clusters of within certain neighborhoods as shown in the open data released by the Toronto Open data site.

# %% [markdown]
# ### Conclusion:
# This goes to affirm that the information in the public domain are very helpful to any new migrant or user of alternative source of transportation to move around various neighborhoods.
